# %% [markdown]
# Data Transformation & Cleaning
#
# **Goal:** Convert hierarchical JSON data into relational tables and perform data cleaning.
#
# **Input:** `mustika_rasa_full.json`
# **Outputs:**
# 1. `df_recipes` (Recipe Metadata)
# 2. `df_ingredients` (Ingredient Details)

# %%
import pandas as pd
import json
import os

# 1. Setup Paths
BASE_DIR = os.getcwd()
INPUT_FILE = os.path.join(BASE_DIR, "mustika_rasa_full_cleaned.json")

# 2. Load JSON Data
try:
    with open(INPUT_FILE, 'r', encoding='utf-8') as f:
        raw_data = json.load(f)
    print(f"Successfully loaded {len(raw_data)} recipes.")
except FileNotFoundError:
    print("Error: JSON file not found. Please ensure 'mustika_rasa_full.json' is in this folder.")
# Out:
# Successfully loaded 1693 recipes.

# %% [markdown]
# ## 1. Flattening the Data
# We will transform the nested JSON into two flat lists to create our relational tables.

# %%
recipes_rows = []
ingredients_rows = []

ing_pk_counter = 1

for recipe in raw_data:
    # --- A. RECIPE TABLE ---
    rec_id = recipe.get('recipe_id')
    
    # Flatten instructions to single string
    instructions_clean = "\n".join(recipe.get('instructions', []) or [])
    
    # Keep tree structure as JSON string for reference
    ing_json_str = json.dumps(recipe.get('ingredient_groups', []), ensure_ascii=False)
    
    recipes_rows.append({
        'id': rec_id,
        'title_original': recipe.get('title_original'),
        'title_normalized': recipe.get('title_normalized'),
        'source_page': recipe.get('_source_page') or recipe.get('page_number'),
        'region': recipe.get('region'),
        'category': recipe.get('category'),
        'ingredient_json': ing_json_str,
        'instruction': instructions_clean
    })
    
    # --- B. INGREDIENTS TABLE ---
    groups = recipe.get('ingredient_groups', [])
    if groups:
        for group in groups:
            g_name = group.get('group_name', 'utama')
            
            for item in group.get('ingredients', []):
                ingredients_rows.append({
                    'id': f"ING_{str(ing_pk_counter).zfill(6)}",
                    'recipe_id': rec_id,
                    'ingredient_group': g_name,
                    'ingredient_original_name': item.get('item_original'),
                    'ingredient_normalized_name': item.get('item_normalized'),
                    'ingredient_quantity': item.get('quantity'),
                    'ingredient_unit': item.get('unit')
                })
                ing_pk_counter += 1

# Create DataFrames
df_recipes = pd.DataFrame(recipes_rows)
df_ingredients = pd.DataFrame(ingredients_rows)

print(f"Recipes Table: {df_recipes.shape}")
print(f"Ingredients Table: {df_ingredients.shape}")
# Out:
# Recipes Table: (1693, 8)
# Ingredients Table: (13786, 7)

# %% [markdown]
# ## 2. Cleaning Recipes Dataset

# %% [markdown]
# ### 2.1 Clean Continues Page Recipes

# %%
# Inspect Recipes
display(df_recipes.head(5))
print(df_recipes.info())
# Out:
#           id     title_original  title_normalized  source_page   region  \
# 0  MR_187_01               ARON              Aron          187  Tengger
# 1  MR_187_02          AREM AREM         Arem Arem          187      NaN
# 2  MR_188_01     AREM AREM ARON    Arem Arem Aron          188      NaN
# 3  MR_189_01  AREM AREM DJAGUNG  Arem Arem Jagung          189      NaN
# 4  MR_190_01       DJAGUNG BOSE       Jagung Bose          190    Timor
#
#         category                                    ingredient_json  \
# 0         Staple  [{"group_name": "utama", "original_header": "B...
# 1   Savory Snack  [{"group_name": "kulit", "original_header": "B...
# 2        Jajanan  [{"group_name": "Bahan Utama (Aron)", "origina...
# 3        Jajanan  [{"group_name": "bahan utama", "original_heade...
# 4  Makanan Pokok  [{"group_name": "utama", "original_header": "B...
#
#                                          instruction
# 0  Bidji jagung direndam air 12 jam atau lebih, s...
# 1  Beras dicuci, dikaru dan digarami.\nJika sudah...
# 2  Aron direndam dengan garam selama ± 5 menit.\n...
# 3  Beras djagung ditjutji bersih, direndam 1 mala...
# 4  Jagung dicuci lalu direndam semalam dalam air....
# <class 'pandas.DataFrame'>
# RangeIndex: 1693 entries, 0 to 1692
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1693 non-null   str
#  1   title_original    1693 non-null   str
#  2   title_normalized  1693 non-null   str
#  3   source_page       1693 non-null   int64
#  4   region            976 non-null    str
#  5   category          1693 non-null   str
#  6   ingredient_json   1693 non-null   str
#  7   instruction       1693 non-null   str
# dtypes: int64(1), str(7)
# memory usage: 105.9 KB
# None

# %%
#check recipes title 
#this data is cleaned through manual edit on json file, ~ 22 recipes was edited manually
df_recipes[df_recipes['id']=='MR_221_01']
# Out:
# Empty DataFrame
# Columns: [id, title_original, title_normalized, source_page, region, category, ingredient_json, instruction]
# Index: []

# %% [markdown]
# ### 2.2 Clean Region

# %%
#check region 
region = df_recipes['region'].value_counts().reset_index()
region
# Out:
#                                 region  count
# 0                              Rembang     78
# 1                                 Bali     76
# 2                           Purwokerto     57
# 3                            Palembang     51
# 4                               Padang     50
# ..                                 ...    ...
# 99   Italia Utara (Serving Suggestion)      1
# 100                            Jalisco      1
# 101           Jawa Tengah - Jawa Timur      1
# 102                         Purworedjo      1
# 103                  Jawa Tengah/Timur      1
#
# [104 rows x 2 columns]

# %%
region_map = {
    # --- JAWA TENGAH ---
    'Rembang': ('Rembang', 'Jawa Tengah'),
    'Purwokerto': ('Purwokerto', 'Jawa Tengah'),
    'Wonosobo': ('Wonosobo', 'Jawa Tengah'),
    'Banyumas': ('Banyumas', 'Jawa Tengah'),
    'Banjumas': ('Banyumas', 'Jawa Tengah'),
    'Bajumas': ('Banyumas', 'Jawa Tengah'),
    'Tegal': ('Tegal', 'Jawa Tengah'),
    'Solo': ('Solo (Surakarta)', 'Jawa Tengah'),
    'Jawa Tengah': ('Jawa Tengah', 'Jawa Tengah'),
    'Djawa Tengah': ('Jawa Tengah', 'Jawa Tengah'),
    'Brebes': ('Brebes', 'Jawa Tengah'),
    'Pati': ('Pati', 'Jawa Tengah'),
    'Kedu': ('Kedu', 'Jawa Tengah'),
    'Magelang': ('Magelang', 'Jawa Tengah'),
    'Cilacap (Tjilatjap)': ('Cilacap', 'Jawa Tengah'),
    'Cilacap': ('Cilacap', 'Jawa Tengah'),
    'Klaten': ('Klaten', 'Jawa Tengah'),
    'Purworedjo': ('Purworejo', 'Jawa Tengah'),
    
    # --- JAWA TIMUR ---
    'Madura': ('Madura', 'Jawa Timur'),
    'Malang': ('Malang', 'Jawa Timur'),
    'Madiun': ('Madiun', 'Jawa Timur'),
    'Jawa Timur': ('Jawa Timur', 'Jawa Timur'),
    'Surabaya': ('Surabaya', 'Jawa Timur'),
    'Pamekasan': ('Pamekasan', 'Jawa Timur'),
    'Magetan': ('Magetan', 'Jawa Timur'),
    'Sumenep': ('Sumenep', 'Jawa Timur'),
    'Tengger': ('Tengger', 'Jawa Timur'),
    'Sumberrejo': ('Sumberejo', 'Jawa Timur'), # Likely Bojonegoro area
    'Pacitan': ('Pacitan', 'Jawa Timur'),
    'Patjitan': ('Pacitan', 'Jawa Timur'),
    'Jawa Tengah - Jawa Timur': ('Jawa Tengah/Timur', 'Jawa Timur'), # Grouping to Jatim/Jateng border
    'Jawa Tengah/Timur': ('Jawa Tengah/Timur', 'Jawa Tengah/Timur'),
    'Sedayu': ('Sedayu', 'Jawa Timur'), # Assuming Gresik context, though Bantul exists

    # --- JAWA BARAT & BANTEN ---
    'Jawa Barat': ('Jawa Barat', 'Jawa Barat'),
    'Djawa Barat': ('Jawa Barat', 'Jawa Barat'),
    'Sukabumi': ('Sukabumi', 'Jawa Barat'),
    'Cianjur': ('Cianjur', 'Jawa Barat'),
    'Tjiandjur': ('Cianjur', 'Jawa Barat'),
    'Bandung': ('Bandung', 'Jawa Barat'),
    'Bogor': ('Bogor', 'Jawa Barat'),
    'Cirebon': ('Cirebon', 'Jawa Barat'),
    'Priangan': ('Priangan', 'Jawa Barat'),
    'Ciamis': ('Ciamis', 'Jawa Barat'),
    'Banten': ('Banten', 'Banten'), # Separated from Jabar for modern context

    # --- DKI JAKARTA ---
    'Jakarta': ('Jakarta', 'DKI Jakarta'),
    'Djakarta': ('Jakarta', 'DKI Jakarta'),
    'Pasarminggu': ('Pasar Minggu', 'DKI Jakarta'),

    # --- DIY YOGYAKARTA ---
    'Jogjakarta': ('Yogyakarta', 'DI Yogyakarta'),
    'Yogyakarta': ('Yogyakarta', 'DI Yogyakarta'),

    # --- BALI & NUSA TENGGARA ---
    'Bali': ('Bali', 'Bali'),
    'Sumbawa': ('Sumbawa', 'Nusa Tenggara Barat'),
    'Lombok': ('Lombok', 'Nusa Tenggara Barat'),
    'Timor': ('Timor', 'Nusa Tenggara Timur'),
    'Flores': ('Flores', 'Nusa Tenggara Timur'),

    # --- SUMATERA ---
    'Palembang': ('Palembang', 'Sumatera Selatan'),
    'Padang': ('Padang', 'Sumatera Barat'),
    'Sumatera Barat': ('Sumatera Barat', 'Sumatera Barat'),
    'Sumatera Barat: Singkarak': ('Singkarak', 'Sumatera Barat'),
    'Batak': ('Batak', 'Sumatera Utara'),
    'Tapanuli': ('Tapanuli', 'Sumatera Utara'),
    'Medan': ('Medan', 'Sumatera Utara'),
    'Atjeh': ('Aceh', 'Aceh'),
    'Aceh': ('Aceh', 'Aceh'),
    'Lampung': ('Lampung', 'Lampung'),
    'Riau': ('Riau', 'Riau'),
    'Duri': ('Duri', 'Riau'), # Assuming Duri Riau
    'Kotagadang': ('Koto Gadang', 'Sumatera Barat'),
    'Singkarak': ('Singkarak', 'Sumatera Barat'),
    'Minangkabau': ('Minangkabau', 'Sumatera Barat'),
    'Minang': ('Minangkabau', 'Sumatera Barat'),
    'Pariaman': ('Pariaman', 'Sumatera Barat'),
    'Bukittinggi': ('Bukittinggi', 'Sumatera Barat'),
    'Pajakumbuh': ('Payakumbuh', 'Sumatera Barat'),
    'Kajutanam': ('Kayu Tanam', 'Sumatera Barat'),
    'Sumatra': ('Sumatera', 'Sumatera'),
    'Kerinci': ('Kerinci', 'Jambi'),

    # --- KALIMANTAN ---
    'Bandjarmasin': ('Banjarmasin', 'Kalimantan Selatan'),
    'Banjarmasin': ('Banjarmasin', 'Kalimantan Selatan'),
    'Samarinda': ('Samarinda', 'Kalimantan Timur'),
    'Kalimantan': ('Kalimantan', 'Kalimantan'),

    # --- SULAWESI ---
    'Menado': ('Manado', 'Sulawesi Utara'),
    'Manado': ('Manado', 'Sulawesi Utara'),
    'Minahasa': ('Minahasa', 'Sulawesi Utara'),
    'Sulawesi Utara': ('Sulawesi Utara', 'Sulawesi Utara'),
    'Makasar': ('Makassar', 'Sulawesi Selatan'),
    'Makassar': ('Makassar', 'Sulawesi Selatan'),
    'Sulawesi Selatan': ('Sulawesi Selatan', 'Sulawesi Selatan'),
    'Bugis': ('Bugis', 'Sulawesi Selatan'),
    'Toraja': ('Toraja', 'Sulawesi Selatan'),
    'Toradja': ('Toraja', 'Sulawesi Selatan'),
    'Djeneponto': ('Jeneponto', 'Sulawesi Selatan'),
    'Palopo': ('Palopo', 'Sulawesi Selatan'),
    'Gorontalo': ('Gorontalo', 'Gorontalo'),
    'Mandar': ('Mandar', 'Sulawesi Barat'),
    'Buton': ('Buton', 'Sulawesi Tenggara'),
    'Poso': ('Poso', 'Sulawesi Tengah'),
    'Sulawesi Utara/Tengah': ('Sulawesi', 'Sulawesi'),

    # --- MALUKU & PAPUA ---
    'Irian Barat': ('Papua', 'Papua'),
    'Ambon': ('Ambon', 'Maluku'),
    'Maluku': ('Maluku', 'Maluku'),
    'Ternate': ('Ternate', 'Maluku Utara'),

    # --- OTHER / UNKNOWN / FOREIGN ---
    'Jawa': ('Jawa', 'Pulau Jawa'), # General
    'Italia Utara (Serving Suggestion)': ('Italia Utara', 'Luar Negeri'),
    'Jalisco': ('Jalisco', 'Luar Negeri'),
}

def map_region(raw_name):
    clean, prov = region_map.get(raw_name, (raw_name, 'Unknown'))
    return pd.Series([clean, prov])

df_recipes[['region_clean', 'province_group']] = df_recipes['region'].apply(map_region)

# %%
df_recipes['province_group'].value_counts()
# Out:
# province_group
# Unknown                717
# Jawa Tengah            291
# Jawa Timur              98
# Sumatera Barat          77
# Bali                    76
# Sulawesi Selatan        59
# Jawa Barat              58
# Sumatera Selatan        51
# Kalimantan Selatan      40
# Sumatera Utara          33
# Sulawesi Utara          26
# Nusa Tenggara Barat     21
# Papua                   17
# DI Yogyakarta           17
# Banten                  16
# Nusa Tenggara Timur     14
# Maluku                  14
# Aceh                    14
# DKI Jakarta             13
# Lampung                  6
# Kalimantan Timur         5
# Gorontalo                5
# Sulawesi Barat           4
# Kalimantan               4
# Sulawesi Tenggara        3
# Riau                     3
# Pulau Jawa               3
# Luar Negeri              2
# Maluku Utara             1
# Sumatera                 1
# Sulawesi                 1
# Jambi                    1
# Sulawesi Tengah          1
# Jawa Tengah/Timur        1
# Name: count, dtype: int64

# %% [markdown]
# ### 2.3 Clean Food Category

# %%
#take data from food_index 
food_index = pd.read_csv('food_index.csv')

# fixing sambal category
food_index[food_index['recipes_original_name'].str.lower().str.startswith('sambal') & (food_index['category'].str.lower() != 'SAMBAL SAMBALAN ')]['category'] = 'SAMBAL SAMBALAN'

display(food_index.head())

food_index['category'].value_counts()
# Out:
# /var/folders/lr/kb1ct1jn4kb5f9k6k7w4tjpw0000gp/T/ipykernel_22278/3087930836.py:5: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   food_index[food_index['recipes_original_name'].str.lower().str.startswith('sambal') & (food_index['category'].str.lower() != 'SAMBAL SAMBALAN ')]['category'] = 'SAMBAL SAMBALAN'
#     recipes_original_name            category
# 0    Sambal Goreng Kering  LAUK PAUK GORENGAN
# 1                   Tempe  LAUK PAUK GORENGAN
# 2             Seng Geseng  LAUK PAUK GORENGAN
# 3               Serundeng  LAUK PAUK GORENGAN
# 4  Serundeng Ikan Mudjair  LAUK PAUK GORENGAN
# category
# DJADJANAN                        649
# LAUK PAUK BASAH TIDAK BERKUAH    454
# LAUK PAUK BASAH - BERKUAH        253
# LAUK PAUK GORENGAN               125
# LAUK PAUK BAKAR                   70
# SAMBAL SAMBALAN                   64
# MAKANAN UTAMA                     46
# MINUMAN                           30
# Name: count, dtype: int64

# %%
# Join index with recipes 

# 1. Rename the existing AI-generated category to avoid collision
df_recipes.rename(columns={'category': 'ai_category'}, inplace=True)

# 2. Create temporary lowercase columns for robust matching
df_recipes['join_key'] = df_recipes['title_original'].str.lower().str.strip()
food_index['join_key'] = food_index['recipes_original_name'].str.lower().str.strip()

# 3. Merge on the lowercase keys
df_recipes = df_recipes.merge(
    food_index[['join_key', 'category']], 
    on='join_key', 
    how='left'
)

# 4. Cleanup: Remove the temporary key
df_recipes.drop(columns=['join_key'], inplace=True)

# %%
#check value count of index

df_recipes['category'] = df_recipes['category'].fillna('Unknown')
df_recipes['category'].value_counts()
# Out:
# category
# DJADJANAN                        593
# LAUK PAUK BASAH TIDAK BERKUAH    423
# LAUK PAUK BASAH - BERKUAH        224
# Unknown                          135
# LAUK PAUK GORENGAN               116
# LAUK PAUK BAKAR                   71
# SAMBAL SAMBALAN                   59
# MAKANAN UTAMA                     45
# MINUMAN                           27
# Name: count, dtype: int64

# %%
# Mapping category using keywords from ai_category and title

# --- 1. Configuration ---

CATEGORIES = {
    'MAKANAN UTAMA': [
        'nasi', 'bubur', 'lontong', 'ketupat', 'tortilla', 'sagu', 'jagung', 'djagung', 'tiwul'
    ],
    'LAUK PAUK BASAH - BERKUAH': [
        'sayur', 'sajur', 'sop', 'soto', 'gulai', 'kare', 'kari', 'lodeh', 'asem', 
        'brongkos', 'rawon', 'semur', 'garang asam', 'gangan', 'pindang', 'santan'
    ],
    'LAUK PAUK BASAH TIDAK BERKUAH': [
        'pepes', 'botok', 'gadon', 'oseng', 'tumis', 'urap', 'pecel', 'petjel', 
        'karedok', 'gudeg', 'gudek', 'rendang', 'kalio', 'sambal goreng', 'sambel goreng', 
        'dendeng', 'terik', 'abon'
    ],
    'LAUK PAUK BAKAR': [
        'sate', 'saté', 'ayam bakar', 'grill', 'ikan bakar', 'panggang', 'klotok'
    ],
    'LAUK PAUK GORENGAN': [
        'goreng', 'perkedel', 'pekedel', 'dadar', 'martabak', 'lumpia', 'risoles', 
        'risolles', 'pastel', 'tahu', 'tempe', 'keripik', 'kerupuk', 'rempeyek', 'bakwan'
    ],
    'SAMBAL SAMBALAN': [
        'sambal', 'sambel', 'saos', 'bumbu', 'petis', 'dabu-dabu'
    ],
    'DJADJANAN': [
        'kue', 'kué', 'cake', 'bolu', 'jajanan', 'snack', 'lapis', 'desert', 'dessert', 
        'dodol', 'jenang', 'djenang', 'wajik', 'wadjid', 'getuk', 'gethuk', 'klepon', 
        'onde', 'apem', 'serabi', 'puding', 'poding', 'agar', 'kolak', 'pisang', 'ubi', 
        'singkong', 'tapai', 'tape', 'empek', 'pempek', 'tekwan', 'batagor', 'siomay'
    ],
    'MINUMAN': [
        'es ', 'minuman', 'wedang', 'bajigur', 'bandrek', 'camilan', 'sirup', 
        'jus', 'kopi', 'teh', 'cendol', 'tjendol', 'dawet'
    ]
}

# --- 2. Helper Functions ---

def get_category(text):
    """
    Maps input text to a category based on keywords.
    Returns 'Unknown' if no match is found or input is not a string.
    """
    if not isinstance(text, str):
        return "Unknown"
    
    text_lower = text.lower()
    
    for category, keywords in CATEGORIES.items():
        for key in keywords:
            # Check for exact word match (regex) OR substring match
            # Note: 'key in text' covers most cases, but regex handles boundaries better.
            if key in text_lower:
                return category
                
    return "Unknown"

def fill_missing_categories(df, source_column, target_column='category'):
    """
    Fills 'Unknown' values in the target_column using the source_column.
    """
    # Identify rows that need processing
    missing_mask = df[target_column] == 'Unknown'
    missing_count = missing_mask.sum()
    
    print(f"--- Processing source: '{source_column}' ---")
    print(f"Rows missing category before processing: {missing_count}")

    if missing_count == 0:
        print("No missing categories found. Skipping.")
        return

    # Extract source text for missing rows and map them
    source_data = df.loc[missing_mask, source_column]
    mapped_values = source_data.apply(get_category)

    # Update DataFrame only where we found a NEW valid category (not 'Unknown')
    # This prevents overwriting an 'Unknown' with another 'Unknown' unnecessarily
    found_mask = mapped_values != 'Unknown'
    
    if found_mask.sum() > 0:
        # We use the index from source_data to align the update correctly
        update_index = source_data[found_mask].index
        df.loc[update_index, target_column] = mapped_values[found_mask]

    # Reporting
    remaining_unknown = (df[target_column] == 'Unknown').sum()
    print(f"Successfully mapped: {found_mask.sum()}")
    print(f"Still Unknown: {remaining_unknown}")
    print("Processing complete.\n")

# --- 3. Execution Logic ---

# Ensure initial missing count is clear
initial_missing = (df_recipes['category'] == 'Unknown').sum()
print(f"Initial missing categories: {initial_missing}\n")

# Step 1: Map using 'ai_category'
fill_missing_categories(df_recipes, source_column='ai_category')

# Step 2: Map using 'title_original' (fallback for remaining unknowns)
fill_missing_categories(df_recipes, source_column='title_original')

# --- 4. Final Inspection ---
final_missing_mask = df_recipes['category'] == 'Unknown'
if final_missing_mask.sum() > 0:
    print("--- Sample of rows that are still Unknown ---")
    print(df_recipes.loc[final_missing_mask, ['title_original', 'ai_category', 'category']].head(5))
else:
    print("All categories have been successfully mapped!")
# Out:
# Initial missing categories: 135
#
# --- Processing source: 'ai_category' ---
# Rows missing category before processing: 135
# Successfully mapped: 92
# Still Unknown: 43
# Processing complete.
#
# --- Processing source: 'title_original' ---
# Rows missing category before processing: 43
# Successfully mapped: 31
# Still Unknown: 12
# Processing complete.
#
# --- Sample of rows that are still Unknown ---
#                   title_original ai_category category
# 301                     TUTURUGA   Main Dish  Unknown
# 302               TUTURUGA PENJU   Lauk Pauk  Unknown
# 337  ATJAR IKAN EMAS (Tjiandjur)   Lauk Pauk  Unknown
# 352                   BABI TJIEN        Lauk  Unknown
# 411       BUNDU DAGING (Makasar)   Main Dish  Unknown

# %%
#Manually Check the remain untidy data

missing_mask = df_recipes['category']=='Unknown'
df_recipes.loc[missing_mask]#[['title_original', 'title_normalized','ai_category','category']]
# Out:
#               id                  title_original         title_normalized  \
# 301    MR_365_02                        TUTURUGA                 Tuturuga
# 302    MR_366_02                  TUTURUGA PENJU           Tuturuga Penyu
# 337    MR_389_01     ATJAR IKAN EMAS (Tjiandjur)  Acar Ikan Mas (Cianjur)
# 352    MR_396_02                      BABI TJIEN                Babi Cien
# 411    MR_432_02          BUNDU DAGING (Makasar)  Bundu Daging (Makassar)
# 412    MR_432_03                   BUNDU MAKASAR           Bundu Makassar
# 459    MR_463_01                    HEE DJIE KEE              Hee Jie Kee
# 503    MR_491_02               LEMPPOK IKAN LAUT         Lempok Ikan Laut
# 594    MR_544_01                          PARAPE                   Parape
# 782    MR_655_01                  DANGKE\n(Duri)            Dangke (Duri)
# 1386   MR_995_03                         Roomnja       Room Vla (Filling)
# 1486  MR_1052_01  Tjara membuat vla dan bahannja      Vla (Custard Sauce)
#
#       source_page    region ai_category  \
# 301           365    Menado   Main Dish
# 302           366    Menado   Lauk Pauk
# 337           389   Cianjur   Lauk Pauk
# 352           396       NaN        Lauk
# 411           432  Makassar   Main Dish
# 412           432  Makassar   Main Dish
# 459           463       NaN   Lauk Pauk
# 503           491   Rembang        Ikan
# 594           544   Makasar   Lauk Pauk
# 782           655      Duri       Dairy
# 1386          995       NaN         Isi
# 1486         1052       NaN        Saus
#
#                                         ingredient_json  \
# 301   [{"group_name": "utama", "original_header": "B...
# 302   [{"group_name": "Bahan utama", "original_heade...
# 337   [{"group_name": "Bahan Utama", "original_heade...
# 352   [{"group_name": "utama", "original_header": "B...
# 411   [{"group_name": "utama", "original_header": "B...
# 412   [{"group_name": "utama", "original_header": "B...
# 459   [{"group_name": "utama", "original_header": "B...
# 503   [{"group_name": "utama", "original_header": "B...
# 594   [{"group_name": "Bahan Utama", "original_heade...
# 782   [{"group_name": "utama", "original_header": "B...
# 1386  [{"group_name": "utama", "original_header": "R...
# 1486  [{"group_name": "vla", "original_header": null...
#
#                                             instruction region_clean  \
# 301   Daging di-potong² ketjil.\nKentang dikupas, di...       Manado
# 302   Daging penju dipotong-potong ketjil.\nBumbu² s...       Manado
# 337   Ikan emas dibersihkan. Kemudian diberi garam d...      Cianjur
# 352   Kentang dikuliti dengan diberi garam sedikit.\...          NaN
# 411   Daging dipotong ketjil².\nKelapa diparut, dibu...     Makassar
# 412   Ajam ditjintjang sampai halus.\nBumbu² direnda...     Makassar
# 459   Dada ajam dipotong lebar tipis.\nHam dan dagin...          NaN
# 503   Nanas dan ikan dibersihkan di-potong².\nBumbu²...      Rembang
# 594   Ikan dipotong-potong, dibersihkan.\nDigoreng s...     Makassar
# 782   Tangkai daun pepaja di-iris², diberi air ½ tja...         Duri
# 1386  1. Kuning telur, gula, mentega, susu, air, ter...          NaN
# 1486  Mula² kuning telur, gula kasar, terigu, menteg...          NaN
#
#         province_group category
# 301     Sulawesi Utara  Unknown
# 302     Sulawesi Utara  Unknown
# 337         Jawa Barat  Unknown
# 352            Unknown  Unknown
# 411   Sulawesi Selatan  Unknown
# 412   Sulawesi Selatan  Unknown
# 459            Unknown  Unknown
# 503        Jawa Tengah  Unknown
# 594   Sulawesi Selatan  Unknown
# 782               Riau  Unknown
# 1386           Unknown  Unknown
# 1486           Unknown  Unknown

# %%
#df_recipes[df_recipes['id']=='MR_221_01']
df_recipes.to_csv('df_recipes.csv')

# %% [markdown]
# # 3. Clean Ingredients
#
# To do:
# 1. Clean ingredient_normalized_name, the tail
# 2. Clean ingredient_group --> how ingredient act at the recipes?
# 2. Categorization of ingredient, modified from: Additive, Bakery, Beverages, Alcoholic Beverages, Cereals,
# Dairy, Essential Oils, Fish, Flowers, Fruit, Fungi, Herbs, Legumes, Maize,
# Meat, Nuts & Seeds, Plants, Seafood, Spices, Vegetables

# %%
# Inspect Ingredients
display(df_ingredients.head(100))
print(df_ingredients.info())
# Out:
#             id  recipe_id ingredient_group ingredient_original_name  \
# 0   ING_000001  MR_187_01            utama    djagung putih pipilan
# 1   ING_000002  MR_187_02            kulit                    beras
# 2   ING_000003  MR_187_02            kulit                    garam
# 3   ING_000004  MR_187_02            kulit         daun pisang batu
# 4   ING_000005  MR_187_02            kulit                   biting
# ..         ...        ...              ...                      ...
# 95  ING_000096  MR_199_01            utama                  djagung
# 96  ING_000097  MR_199_01            utama              nangka muda
# 97  ING_000098  MR_199_02            utama                  djagung
# 98  ING_000099  MR_199_02            utama                 ubi kaju
# 99  ING_000100  MR_199_03            utama                     nasi
#
#    ingredient_normalized_name ingredient_quantity ingredient_unit
# 0        jagung putih pipilan                None             NaN
# 1                       beras                 1.0           liter
# 2                       garam                 1.0    sendok makan
# 3            daun pisang batu                 2.0         pelepah
# 4                      biting                None      secukupnya
# ..                        ...                 ...             ...
# 95                     jagung                 0.5              kg
# 96                nangka muda                 0.5            buah
# 97                     jagung                 1.0              kg
# 98                   ubi kayu                 2.0              kg
# 99                       nasi                 1.0              kg
#
# [100 rows x 7 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 13818 entries, 0 to 13817
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          13818 non-null  str
#  1   recipe_id                   13818 non-null  str
#  2   ingredient_group            13818 non-null  str
#  3   ingredient_original_name    13818 non-null  str
#  4   ingredient_normalized_name  13818 non-null  str
#  5   ingredient_quantity         13189 non-null  object
#  6   ingredient_unit             13608 non-null  str
# dtypes: object(1), str(6)
# memory usage: 755.8+ KB
# None

# %%
counts = df_ingredients['ingredient_group'].str.lower().value_counts()

# Only show ingredients that appear 5 times or less
rare_ingredients = counts[counts <= 5] 
rare_ingredients
# Out:
# ingredient_group
# kulit                                    5
# bumbu tambahan                           5
# alas nanas                               5
# sebelah bawah                            5
# bahan isi                                5
# sambal                                   5
# glazuur                                  5
# bahan_instruksi_tambahan                 4
# lain-lain                                4
# adonan_laksan                            4
# bumbu_saos                               4
# tambahan (dari instruksi)                4
# bumbu (lanjutan)                         4
# bahan enten                              4
# saos (bumbu halus)                       4
# kepala (topping)                         4
# bahan lain (diekstrak dari instruksi)    4
# wadjud kelapa                            4
# cream                                    4
# keterangan_pelengkap                     3
# bahan_utama_inferred                     3
# pemanis                                  3
# enten                                    3
# saos (tambahan)                          3
# sebelah atas                             3
# kulit/bahan dasar                        3
# santan kental                            3
# bahan tambahan                           3
# bahan utama (aron)                       2
# bahan_utama_dan_pelengkap                2
# utama (inferred)                         2
# bahan_dasar_saos                         2
# utama_lanjutan                           2
# saos tambahan (inferred)                 2
# utama dan bumbu pelengkap                2
# perisa                                   2
# sirup                                    2
# bumbu/pelengkap                          1
# inti                                     1
# utama (sambungan)                        1
# isi                                      1
# gula                                     1
# adonan (lanjutan)                        1
# Name: count, dtype: int64

# %%
df_ingredients['ingredient_normalized_name'] = df_ingredients['ingredient_normalized_name'].str.lower()
df_ingredients['ingredient_normalized_name'].value_counts()
# Out:
# ingredient_normalized_name
# garam                  1303
# bawang merah            780
# bawang putih            690
# kelapa                  535
# gula merah              416
#                        ...
# sirup vanili              1
# es parut                  1
# es dan gula               1
# biji sagu                 1
# tape ketan/singkong       1
# Name: count, Length: 1277, dtype: int64

# %%
counts.to_csv('counts.csv')

# %%
counts = df_ingredients['ingredient_original_name'].value_counts()

# Only show ingredients that appear 5 times or less
rare_ingredients = counts[counts <= 5] 

with pd.option_context('display.max_rows', None):
    print(rare_ingredients)
# Out:
# ingredient_original_name
# beras djagung                                                        5
# daun kelor                                                           5
# daun turi                                                            5
# asam sunti                                                           5
# santan tjair                                                         5
# buah melindjo                                                        5
# telur itik                                                           5
# daun mangkokan                                                       5
# ikan teri                                                            5
# udang ketjil                                                         5
# daun so                                                              5
# nanas                                                                5
# ikan peda                                                            5
# irisan bawang merah                                                  5
# ikan                                                                 5
# bawang merah iris                                                    5
# ikan belanak                                                         5
# mangga muda                                                          5
# tepung panir                                                         5
# daun selada                                                          5
# susu kental                                                          5
# gula merah halus                                                     5
# gula pasir halus                                                     5
# tjoklat                                                              5
# kuning telur ajam                                                    5
# ketela pohon                                                         5
# daun pisang batu                                                     4
# lidi                                                                 4
# gaplek                                                               4
# daun sereh                                                           4
# gadjih                                                               4
# kedju                                                                4
# waluh djipang                                                        4
# daun katuk                                                           4
# daun katjang pandjang                                                4
# belondo                                                              4
# taoge kedele                                                         4
# daun pakis                                                           4
# labu                                                                 4
# ikan kembung                                                         4
# saus tomat                                                           4
# daun ruku²                                                           4
# lombok merah halus                                                   4
# lombok giling                                                        4
# djengkol                                                             4
# ketjap manis                                                         4
# air asam                                                             4
# daun lumbu                                                           4
# ikan asin                                                            4
# tomat besar                                                          4
# ikan panggang                                                        4
# petis udang                                                          4
# saos tomat                                                           4
# kedele                                                               4
# ikan emas                                                            4
# teri kering                                                          4
# pisang batu muda                                                     4
# ikan tenggiri                                                        4
# kertas minjak                                                        4
# taoege                                                               4
# tjengkeh halus                                                       4
# tusukan sate                                                         4
# santan entjer                                                        4
# agar²                                                                4
# gula aren                                                            4
# nangka masak                                                         4
# kandji                                                               4
# warna                                                                4
# gula siwalan                                                         4
# bakpoeder                                                            4
# durian                                                               4
# tape                                                                 4
# susu segar                                                           4
# putihnja telur                                                       4
# minjak samin                                                         3
# kapur                                                                3
# tahu besar                                                           3
# kikil                                                                3
# labu kuning                                                          3
# kunijt                                                               3
# daun ubi kaju                                                        3
# asam sunti/belimbing wuluh                                           3
# labu air                                                             3
# daging penju                                                         3
# kedelai                                                              3
# terong besar                                                         3
# daging tetelan                                                       3
# ertjis                                                               3
# daun kol                                                             3
# katjang idjo                                                         3
# asam muda                                                            3
# djamur padi                                                          3
# bawang goreng                                                        3
# kaldu ajam                                                           3
# gurami                                                               3
# ikan ketjil²                                                         3
# daun arago                                                           3
# kedele hitam                                                         3
# daun talas                                                           3
# tepung roti                                                          3
# djeruk sitrun                                                        3
# ikan laut/tawar                                                      3
# tepung kunjit                                                        3
# bandeng                                                              3
# lidah sapi                                                           3
# kemiri dibakar                                                       3
# tomat masak                                                          3
# ikan gurami                                                          3
# kelapa diparut                                                       3
# telur ajam/itik                                                      3
# air asem                                                             3
# brambang                                                             3
# parutan kelapa                                                       3
# katjang goreng                                                       3
# blondo                                                               3
# belimbing                                                            3
# ragi                                                                 3
# tape singkong                                                        3
# kelapa (santan kental)                                               3
# air daun pandan                                                      3
# selai nanas                                                          3
# kaju manis halus                                                     3
# bekatul djagung                                                      3
# menir djagung                                                        3
# katjang²an                                                           3
# air masak                                                            3
# air pandan                                                           3
# soda                                                                 3
# air dingin                                                           3
# tepung tapioka                                                       3
# daging/ajam                                                          2
# djinten putih                                                        2
# djinten manis                                                        2
# abon                                                                 2
# ketimun muda                                                         2
# bawah putih                                                          2
# katjang tunggak                                                      2
# beras putih                                                          2
# kuah daging                                                          2
# dada ajam                                                            2
# salada                                                               2
# tetelan                                                              2
# daun mengkudu                                                        2
# daging/tulang                                                        2
# ekor sapi                                                            2
# kunjit bubuk                                                         2
# bumbu arab                                                           2
# ikan kaju                                                            2
# kerupuk kulit                                                        2
# daun singkong muda                                                   2
# asam gelugur                                                         2
# daun ubi djalar                                                      2
# tomat muda                                                           2
# ajam gemuk                                                           2
# kentang ketjil²                                                      2
# bawang merah diiris                                                  2
# daun kangkung                                                        2
# hati                                                                 2
# hondje                                                               2
# kepok                                                                2
# susu sapi                                                            2
# pare ajam                                                            2
# sawi                                                                 2
# sawi hidjau                                                          2
# buah kelor                                                           2
# terong ketjil                                                        2
# katjang putih                                                        2
# kundjit                                                              2
# udang segar                                                          2
# djeruk limo                                                          2
# djamur kuping                                                        2
# lompong                                                              2
# lumbu                                                                2
# sawi putih                                                           2
# daging berlemak                                                      2
# tomat sedang                                                         2
# gula kelapa                                                          2
# tomat hidjau                                                         2
# prei diiris                                                          2
# djamur pajung                                                        2
# bumbu kare                                                           2
# asperges                                                             2
# ham                                                                  2
# macaroni                                                             2
# lada bulat                                                           2
# lobak                                                                2
# telur rebus                                                          2
# tomat jang besar                                                     2
# anggur                                                               2
# ajam muda                                                            2
# bunga turi                                                           2
# ketimun besar                                                        2
# daun keladi                                                          2
# sajur asin                                                           2
# kunjit tepung                                                        2
# tempodjak                                                            2
# telur ajam/bebek                                                     2
# minjak goreng atau mentega                                           2
# lamtoro                                                              2
# katak                                                                2
# ikan tawes                                                           2
# kemiri bakar                                                         2
# gula putih                                                           2
# dages                                                                2
# ikan bambangan                                                       2
# daun sembukan                                                        2
# kaldu ikan                                                           2
# ikan pipih                                                           2
# terong glatik                                                        2
# laksa                                                                2
# daging tjintjang                                                     2
# gereh tongkol                                                        2
# djuhi                                                                2
# bihun                                                                2
# ikan gabus/belida jang telah dihaluskan                              2
# bawang merah halus                                                   2
# darah ajam                                                           2
# daging lulur                                                         2
# minjak samin/margarine                                               2
# daun bawang merah                                                    2
# ikan mas                                                             2
# kunjit halus                                                         2
# daging sapi atau kambing                                             2
# djeruk sundai (sitroen)                                              2
# bunga pisang kepok                                                   2
# tempe bungkil                                                        2
# pare                                                                 2
# daun sawi                                                            2
# katjang putih kering                                                 2
# ikan lele                                                            2
# kelapa jang muda                                                     2
# teri nasi                                                            2
# sungsum                                                              2
# tomat merah                                                          2
# isi perut kambing                                                    2
# terung                                                               2
# darah babi                                                           2
# ampas kelapa                                                         2
# darah                                                                2
# pipilan djagung muda                                                 2
# kulit babi                                                           2
# bumbu arabia                                                         2
# ubi djalalar                                                         2
# tepung sagu kering                                                   2
# tahu sedang                                                          2
# tepung beras/terigu                                                  2
# daging kambing bergemuk                                              2
# ikan teri basah                                                      2
# daun sagu                                                            2
# daun paku                                                            2
# andaliman                                                            2
# bandeng jang besar                                                   2
# djahe                                                                2
# tepung ubi kaju                                                      2
# gula pasir/merah                                                     2
# sagu mutiara                                                         2
# biang roti                                                           2
# tepung gula                                                          2
# jam                                                                  2
# sukade                                                               2
# manisan djae                                                         2
# sirop gula merah                                                     2
# djagung tua                                                          2
# tepung katjang hidjau                                                2
# pelok                                                                2
# abu merang                                                           2
# ikan halus                                                           2
# emping                                                               2
# beras ketan putih                                                    2
# tjenkeh                                                              2
# pandan wangi                                                         2
# havermout                                                            2
# air santan                                                           2
# kedju diparut atau ditjintjang                                       2
# gula merah/pasir                                                     2
# daun kelapa muda                                                     2
# daun pandan besar                                                    2
# air hangat                                                           2
# talas                                                                2
# iris²an kenari                                                       2
# putih telur ajam                                                     2
# kenari tjintjang                                                     2
# amandel                                                              2
# minjak sitrun                                                        2
# citroen essence                                                      2
# air soda                                                             2
# pepaja                                                               2
# mi                                                                   2
# djambu bidji                                                         2
# merahnja telur                                                       2
# sukun                                                                2
# es                                                                   2
# air mentah                                                           2
# djagung putih pipilan                                                1
# djagung bidji tua                                                    1
# daun waluh                                                           1
# djagung kering pipilan                                               1
# daging klapstuk                                                      1
# djagung tua pipilan                                                  1
# kulit ketupat (sedang)                                               1
# pisang kepok atau pisang radja jang tua                              1
# kulit lontong                                                        1
# daun pisang/kulit ketupat                                            1
# susu asam                                                            1
# kas²                                                                 1
# bumbu korma                                                          1
# kulit manis                                                          1
# djagung bidji setengah tua                                           1
# pasta tortilla                                                       1
# katjang                                                              1
# radis                                                                1
# kulit melindjo                                                       1
# ikan jang telah didjemur                                             1
# daun dan batang talas                                                1
# buntjis/katjang pandjang                                             1
# lombok tjamparan                                                     1
# daun labu                                                            1
# menir katjang hidjau                                                 1
# daging tetelan dan tulang                                            1
# anak pohon pisang bidji                                              1
# daun belimbing setengah tua                                          1
# kantjang pandjang                                                    1
# daun katjang                                                         1
# taoge katjang hidjau                                                 1
# roroban                                                              1
# batang anak pisang                                                   1
# tungkul                                                              1
# daun ruku                                                            1
# asam potong                                                          1
# batang talas (birah)                                                 1
# daging (udang kering)                                                1
# rimbang                                                              1
# daging, usus, babat, paru, hati, gemuk                               1
# daun kunir                                                           1
# katak hidjau                                                         1
# sungsum kambing/sapi                                                 1
# kerupuk djangot                                                      1
# kuskus                                                               1
# labu parang                                                          1
# kalapa                                                               1
# daging bergemuk                                                      1
# otak sapi                                                            1
# kelapa jang tua                                                      1
# daging kambing/sapi atau ajam                                        1
# ikan djambal                                                         1
# paria                                                                1
# pisang kepok muda                                                    1
# pliëk ue                                                             1
# udang/tiram                                                          1
# teri basah                                                           1
# daging sup                                                           1
# katjang buntjis kering                                               1
# daun tapak liman                                                     1
# balungan                                                             1
# kaki sapi/kerbau                                                     1
# daging kambing/sapi                                                  1
# bawang putih diiris                                                  1
# gardamunggu                                                          1
# udang/kerang                                                         1
# daun ubi                                                             1
# kelapa/santan                                                        1
# kaldu penju                                                          1
# peterseli                                                            1
# daun singkong karet muda                                             1
# pete                                                                 1
# ikan tjutjut                                                         1
# tempe semangit                                                       1
# rese udang                                                           1
# ikan kakap atau tongkol                                              1
# ikan tjutjut panggang                                                1
# ikan basah                                                           1
# tomat ketjil                                                         1
# daging ajam/sapi                                                     1
# djeruk purut (kulitnja)                                              1
# batang keladi                                                        1
# kaldu daging atau air biasa                                          1
# asam muda atau belimbing wuluh                                       1
# katjang rudji                                                        1
# tulang²                                                              1
# wuluh djipang                                                        1
# ikan pepuju                                                          1
# tetelan daging                                                       1
# daun tjikra-tjikri                                                   1
# gram                                                                 1
# lembajung muda                                                       1
# petsai                                                               1
# daun semanggi                                                        1
# takokak                                                              1
# pisang muda                                                          1
# batang pisang                                                        1
# bunga melindjo                                                       1
# gambas/ojong                                                         1
# katjang merah/katjang gadjih                                         1
# garam.                                                               1
# keluwih                                                              1
# ketjambah kedele                                                     1
# tulang iga                                                           1
# sedap malam                                                          1
# bambu (potongan bambu)                                               1
# gereh petek                                                          1
# kunji t                                                              1
# dj ae                                                                1
# daging/tetelan                                                       1
# daun melindjo dengan buahnja                                         1
# bajam atau sajuran lain (daun kelor, daun katuk)                     1
# pepaja muda jang sedang                                              1
# putjuk labu                                                          1
# ikan laut (kapasan)                                                  1
# ber-matjam sajuran                                                   1
# daun                                                                 1
# ikan petek atau bukur                                                1
# taoge kedelai                                                        1
# undis                                                                1
# bunga kembodja putih                                                 1
# djagung sedang                                                       1
# djeroan bebek (isi perut)                                            1
# ikan kemamah                                                         1
# kembang kates                                                        1
# ketjap kental                                                        1
# kretjek                                                              1
# telur bebek/ajam                                                     1
# telur bebek atau telur ajam                                          1
# minjak/margarine                                                     1
# ikan tambak                                                          1
# lidah                                                                1
# terong ungu                                                          1
# seledri iris                                                         1
# bajam keong                                                          1
# mosterd                                                              1
# lombok hidjau diiris                                                 1
# irisan seledri                                                       1
# irisan prei                                                          1
# spek                                                                 1
# ikan banjar                                                          1
# bunga kol                                                            1
# roti goreng dipotong ketjil-ketjil.                                  1
# telur direbus jang keras.                                            1
# daging rebus dipotong sebesar dadu.                                  1
# kepiting bertelur                                                    1
# sagu (kandji)                                                        1
# champignon                                                           1
# sarang burung                                                        1
# daging dan tetelan                                                   1
# tortilla                                                             1
# kuning isi telur                                                     1
# daging kambing/sapi jang berlemak                                    1
# isi perut                                                            1
# minyak                                                               1
# tauge                                                                1
# keripik kentang                                                      1
# selada air                                                           1
# daun selasih                                                         1
# daun kuntjai                                                         1
# daun djinten                                                         1
# daun djintan                                                         1
# daun peterseli                                                       1
# selasih                                                              1
# tepung roti kering                                                   1
# makaroni                                                             1
# santan lainnja                                                       1
# kaldu babi                                                           1
# minjak/gadjih                                                        1
# bunga pepaja                                                         1
# batang pisang jang muda (bagian dalam)                               1
# hati ajam                                                            1
# tjuka larutan                                                        1
# djagung jang muda sekali (putik djagung)                             1
# bawang merah dibelah                                                 1
# bawang putih diiris tipis                                            1
# daun dan tangkai talas                                               1
# ikan (biasanja tjakalang)                                            1
# minjak babi/gadjih                                                   1
# tulang iga babi (bakut)                                              1
# lombokrawit                                                          1
# ketjap putih (ketjap tjina)                                          1
# daging babi jang berkulit                                            1
# tjabe                                                                1
# belut                                                                1
# ikan salai                                                           1
# petai (djika disukai)                                                1
# teri segar                                                           1
# ikan belida                                                          1
# ikan air tawar                                                       1
# minyak kelapa                                                        1
# djeroan sapi berlemak                                                1
# djagung muda dipipil                                                 1
# pisang batu jang muda                                                1
# ajam dara                                                            1
# perkedel ketjil                                                      1
# daun melinjo                                                         1
# lombok hijau                                                         1
# belenjik                                                             1
# laos parut                                                           1
# lombok merah/rawit                                                   1
# djamur gigit                                                         1
# juju                                                                 1
# lobok rawit                                                          1
# daun pisang klutuk                                                   1
# gula mera                                                            1
# daun lempujang muda (lireh)                                          1
# ikan wagal/laut                                                      1
# mlandingan                                                           1
# blimbing wuluh                                                       1
# putren                                                               1
# ikan asin/peda                                                       1
# batang pisang muda (ares)                                            1
# daun belimbing ½ tua                                                 1
# kulit sapi                                                           1
# darah sapi                                                           1
# irisan kentjur                                                       1
# ikan peda atau ikan kering asin                                      1
# djerami merang                                                       1
# kulit djeruk                                                         1
# daging sapi atau babi                                                1
# lombok merah segar                                                   1
# lombok merah kering                                                  1
# asam sundai                                                          1
# djagung segar                                                        1
# seledri di-potong²                                                   1
# irisan lombok                                                        1
# ikan pihi                                                            1
# daun belimbing                                                       1
# terong lalab                                                         1
# pisang batu jang masih muda                                          1
# buah paria                                                           1
# santan kelapa kental                                                 1
# daging jang berlemak                                                 1
# telur ajam atau bebek                                                1
# tulang babi                                                          1
# gadjih atau minjak babi                                              1
# kulit kerbau atau kulit sapi                                         1
# rebung di iris²                                                      1
# djeruk sundai (citroen)                                              1
# anak pohon pisang                                                    1
# batu                                                                 1
# keluwek                                                              1
# hati sapi                                                            1
# kol hidjau                                                           1
# tulang² sapi                                                         1
# manggar muda                                                         1
# ikan gabus kering                                                    1
# pondoh                                                               1
# champignon (djamur)                                                  1
# tepung terigu (sagu)                                                 1
# rebung jang sudah direbus                                            1
# lad halus                                                            1
# daun tales                                                           1
# kulit kerang                                                         1
# ikan mairo                                                           1
# ikan laut jang ketjil                                                1
# daging ajam bagian dalam (hati, gemuk, dll) di-iris²                 1
# lombok merah/ rawit                                                  1
# pakis jang muda                                                      1
# paria besar                                                          1
# kunjit seudjung                                                      1
# lidah lembu                                                          1
# entjes                                                               1
# daun krema                                                           1
# lembajung                                                            1
# laos muda                                                            1
# ikan belida jang telah dihaluskan                                    1
# daun ganda                                                           1
# ikan jang telah dihaluskan (gabua, belida, tenggiri)                 1
# tepung biskuit                                                       1
# air/kaldu                                                            1
# daging sapi/kambing                                                  1
# mentega/minjak goreng                                                1
# daging lulur dalam                                                   1
# kelapa parut digoreng, ditumbuk                                      1
# sapi/babi + kulitnja daging ajam/babi                                1
# daging babi jang berlemak                                            1
# keluwih muda                                                         1
# kulit daging                                                         1
# nanas ½ masak                                                        1
# bubuk biskuit                                                        1
# margarine/mentega                                                    1
# lombok merah besar                                                   1
# daun talas muda                                                      1
# daging ajam atau kambing                                             1
# minjak sapi                                                          1
# lembaran gemuk kambing                                               1
# hati kambing                                                         1
# daging sapi atau kerbau                                              1
# air asam/tjuka                                                       1
# ikan mas (lele, gabus)                                               1
# lokio dengan daunnja                                                 1
# ikan laut atau ikan lain                                             1
# djeruk sitroen                                                       1
# minjak samin atau margarine                                          1
# terung pandjang                                                      1
# batang hondje                                                        1
# asam sundai (djeruk sitroen)                                         1
# kelapa sangan digiling halus                                         1
# ikan tawes, dll, ikan air tawar                                      1
# kulit kaju siken diperas                                             1
# airnja                                                               1
# darah dari sapi atau kambing                                         1
# kulit kaju siken diperas airnja                                      1
# tulang berdaging dari sapi, babi atau kerbau                         1
# putjuk kunjit                                                        1
# daun murbei                                                          1
# bia kering                                                           1
# sisa sajur lodeh                                                     1
# sisa atjar                                                           1
# sisa sambal goreng                                                   1
# kol atau buntjis                                                     1
# lombok merah (sudah dibuangi isinja)                                 1
# garam, pala, lada                                                    1
# pindang                                                              1
# lada laos                                                            1
# tempe kedele                                                         1
# gendjer                                                              1
# lombok merah/hidjau                                                  1
# kroto                                                                1
# ikan tinumbu                                                         1
# laksa rebus                                                          1
# kentang rebus                                                        1
# daging bersama tulangnja                                             1
# ikan mairo (teri)                                                    1
# ikan tjakalang                                                       1
# laos iris                                                            1
# ikan laut basah                                                      1
# tjuka atau djeruk nipis                                              1
# ikan sepat                                                           1
# buah tapi                                                            1
# air panas/masak                                                      1
# lempujang                                                            1
# tawon madu jang masih muda didalam tala                              1
# ajam sedang                                                          1
# kelapa untuk diparut                                                 1
# djatung pisang                                                       1
# bunga ketjombrang                                                    1
# lobok merah                                                          1
# gula merah atau gula pasir                                           1
# galendo                                                              1
# duan bawang                                                          1
# ketek                                                                1
# daun mengkudu muda                                                   1
# djeroan ikan bandeng                                                 1
# daun mengkudu muda jang lebar                                        1
# telur ikan                                                           1
# tawon muda                                                           1
# tjendawan bulan (tumbuh dibawah pohon pisang dalam musim hudjan)     1
# petis ikan                                                           1
# bajem                                                                1
# ajam betina                                                          1
# ikan panggang laut                                                   1
# ojong (petola)                                                       1
# pisang kepok mentah                                                  1
# lombok rawit hidjau                                                  1
# tulang sapi (iga)                                                    1
# ikan tandjan                                                         1
# ikan balang                                                          1
# daun djambu bidji                                                    1
# kepiting                                                             1
# prei putih                                                           1
# ikan bawal                                                           1
# daging babi atau sapi                                                1
# bia putih                                                            1
# buah melidjo                                                         1
# daging babi dengan djeroan                                           1
# djreuk nipis                                                         1
# telor ajam                                                           1
# ikan kakap/tenggiri                                                  1
# dopertwen                                                            1
# mayonaise                                                            1
# minjak selada                                                        1
# daun tomat                                                           1
# terung ketjil                                                        1
# udang laut                                                           1
# ketjambah katjang tolo                                               1
# kwini                                                                1
# mentega atau margarine                                               1
# bawang daun                                                          1
# roti marie bubuk                                                     1
# ...
# ikan jang telah dihaluskan (gabus, belida, tenggiri)                 1
# lombok dan garam                                                     1
# daging ikan (tenggiri)                                               1
# telur itik rebus                                                     1
# pisang masak                                                         1
# krupuk                                                               1
# tepung beras/ terigu                                                 1
# ketela/ubi                                                           1
# gadung                                                               1
# tepung beras ketan/djawa                                             1
# londo merang                                                         1
# essence framboos                                                     1
# sirsak                                                               1
# tales                                                                1
# pepaja setengah masak                                                1
# bekasang                                                             1
# daging jang bertulang                                                1
# rumput laut                                                          1
# ketan hitam/putih                                                    1
# daun djambu air                                                      1
# sagu basah jang telah disaring                                       1
# ketan putih/hitam                                                    1
# kaju manis ditumbuk                                                  1
# tuak atau air tape                                                   1
# kulit djagung muda                                                   1
# tawas                                                                1
# sarang ketupat                                                       1
# atji ubi kaju                                                        1
# djagung hampir tua                                                   1
# pisang nangka                                                        1
# kolang-kaling                                                        1
# labu merah jang tua                                                  1
# pandan atau panili                                                   1
# daging ikan bandeng jang dibuang durinja                             1
# beras tjantel (tjantel)                                              1
# gatot gadung kering                                                  1
# santan kanil                                                         1
# kembang roti                                                         1
# daun pandan (ditumbuk)                                               1
# tjoklat dan kismis                                                   1
# kelapa (santan)                                                      1
# lada dan garam                                                       1
# vla room kental                                                      1
# buah²an dalam kaleng                                                 1
# margarine/minjak samin                                               1
# djagung pipihan                                                      1
# katjang temo                                                         1
# selai (vla room)                                                     1
# ketan hitam atau ketan putih                                         1
# pelepah pisang kering atau daun pisang kering                        1
# pelepah pisang                                                       1
# pisang nangka/tanduk                                                 1
# parutan kulit djeruk purut                                           1
# tepung terigu/ beras                                                 1
# tepung kentang                                                       1
# tepung singkong/maizena                                              1
# warna makanan                                                        1
# air es                                                               1
# pewarna merah                                                        1
# warna merah hidjau                                                   1
# bahan warna                                                          1
# bidji mote (mutiara)                                                 1
# kelapa sudah tua                                                     1
# nenas diparut                                                        1
# tape beras                                                           1
# tepung hunkwe                                                        1
# kelapa muda parut                                                    1
# kelapa jang diparut                                                  1
# warna kue merah/hidjau                                               1
# getuk mawur                                                          1
# sagu merah/putih                                                     1
# air kapur djernih                                                    1
# warna merah                                                          1
# ubi djalar merah                                                     1
# air gula merah                                                       1
# air atau santan tjair                                                1
# tepung pati djagung                                                  1
# gula pasir (aren)                                                    1
# ubi djalar kuning                                                    1
# bumbu spekkoek                                                       1
# sagu ambon                                                           1
# pisang kepok                                                         1
# bambu muda                                                           1
# putjuk daun pisang                                                   1
# djinten giling                                                       1
# brambang bawang                                                      1
# tongkol                                                              1
# daun selasi                                                          1
# daun vinkel                                                          1
# daun laurier                                                         1
# lada butir                                                           1
# karuk ketan                                                          1
# santan kental/susu                                                   1
# pisang radja masak tua                                               1
# daun pisang sebagai pembungkus                                       1
# mihun                                                                1
# kubis                                                                1
# lontjang                                                             1
# seledri kutjaj                                                       1
# ikan gabus/belida                                                    1
# daun sop/seledri                                                     1
# padi sisa jang ketinggalan diladang                                  1
# gabah padi jang belum tua                                            1
# gula pasir atau gula aren                                            1
# singkong (sabrang)                                                   1
# katjang oto                                                          1
# gula aren di-iris²                                                   1
# pati garut                                                           1
# air kelapa/air soda                                                  1
# daun dan tangkai bete                                                1
# gula kasar                                                           1
# pepaja mentah                                                        1
# gula, garam                                                          1
# bawang merah, terasi, daun djeruk purut                              1
# pisang tanduk/ pisang nangka                                         1
# pisang kaju                                                          1
# ardbei                                                               1
# irisan djagung muda                                                  1
# kuningnja telur                                                      1
# pati djagung                                                         1
# kelapa kopjor                                                        1
# tjoklat bubuk                                                        1
# semat/biting                                                         1
# kelapa muda diparut                                                  1
# peujeum (tape)                                                       1
# essence frambosen                                                    1
# batang bambu                                                         1
# kelapa parutan                                                       1
# gula pandan wangi                                                    1
# garam bersih                                                         1
# paneermeel                                                           1
# minjak barco                                                         1
# roti kering (pannermeel)                                             1
# tepung beras/                                                        1
# air soda atau air kelapa                                             1
# adonan roti                                                          1
# panili bubuk                                                         1
# putih telur (diambil dari lain telur)                                1
# 4 petis                                                              1
# tungtjai                                                             1
# semanggi                                                             1
# mie basah                                                            1
# timun muda                                                           1
# kerupuk merah                                                        1
# kawista                                                              1
# nangka tua belum masak                                               1
# dedak djagung                                                        1
# nasi ketan                                                           1
# abon sapi/ajam                                                       1
# kelapa muda (diparut)                                                1
# daun sup                                                             1
# sagu mentah                                                          1
# getuk dari ketela pohon                                              1
# kakkala (gaplek)                                                     1
# sagu/gaplek                                                          1
# selai nenas                                                          1
# tepung maizena atau tepung singkong                                  1
# minjak kaju manis                                                    1
# minjak tjengkeh                                                      1
# minjak pala                                                          1
# kapulaga jang sudah ditumbuk halus                                   1
# pisang radja masak                                                   1
# tepung beschuit                                                      1
# vanili                                                               1
# nenas, kismis, sukade                                                1
# bubuk susu                                                           1
# essence panili                                                       1
# selai nenas atau selai lain                                          1
# bischuit mari                                                        1
# brandy                                                               1
# extract kopi                                                         1
# nasi lembek                                                          1
# selai ardbei                                                         1
# gintju warna kuning                                                  1
# kedondong                                                            1
# tape ubi                                                             1
# katul                                                                1
# minjak katjang                                                       1
# singkong/gaplek                                                      1
# gula djawa/kelapa                                                    1
# pisang radja (siem)                                                  1
# telor                                                                1
# zat warna merah/hidjau                                               1
# zat warna kue                                                        1
# nangka jang di-iris²                                                 1
# ikan gabus halus                                                     1
# djinten hitam                                                        1
# pati singkong                                                        1
# getuk ketela pohon                                                   1
# pisang kepok masak benar                                             1
# tape ketan                                                           1
# essence                                                              1
# tepung sagu (kering)                                                 1
# susu kental manis                                                    1
# kopi                                                                 1
# kolang kaling                                                        1
# anggu buah²an                                                        1
# buah atap                                                            1
# ketimun suri                                                         1
# rambuata                                                             1
# cacao                                                                1
# adpokat matang                                                       1
# kopi extract                                                         1
# air zuursak                                                          1
# buah²an kaleng                                                       1
# daging kelapa muda                                                   1
# tepung tjoklat                                                       1
# air sirsak                                                           1
# susu kental (manis)                                                  1
# sagu bidji delima                                                    1
# tjintjau                                                             1
# daun tjintjao                                                        1
# bawang merah jang dibakar dahulu                                     1
# djeruk sundai (sitrun)                                               1
# mangga kuweni                                                        1
# bidji delima                                                         1
# sitrun                                                               1
# gintju merah                                                         1
# sirop panili                                                         1
# es parut                                                             1
# es dan gula                                                          1
# aren                                                                 1
# bidji sagu                                                           1
# tape ketan/ketela pohon                                              1
# Name: count, dtype: int64

# %%
import pandas as pd
import re

# Load your data (assuming it's already in a DataFrame named df)
# df = pd.read_csv('your_data.csv')

def clean_ingredient_name(text):
    if not isinstance(text, str):
        return ""
    
    # 1. Lowercase and strip whitespace
    text = text.lower().strip()
    
    # 2. Remove text inside parentheses (usually states/quantities like "1/2 tua" or "(iris)")
    text = re.sub(r'\([^)]*\)', '', text)
    
    # 3. Handle "/" - usually "minyak/mentega". We take the first item as primary.
    if '/' in text:
        text = text.split('/')[0]
        
    # 4. Remove specific noise characters and numbers
    text = re.sub(r'[0-9½¼\.,]', '', text) 
    
    # 5. OLD SPELLING NORMALIZATION (The "Ejaan Lama" Fixer)
    # Note: Order matters.
    replacements = {
        'oe': 'u',
        'dj': 'j',
        'tj': 'c',
        'nj': 'ny',
        'sj': 'sy',
        'ch': 'kh',
        'j': 'y' # Be careful: 'j' in old spelling was often 'y' sound, but 'dj' was 'j'. 
                  # In this specific dataset context, 'ajam' -> 'ayam' supports this rule.
    }
    
    # Apply replacements strictly (token-based or careful substring)
    # We iterate through the map. 
    for old, new in replacements.items():
        # Handle "ajam" -> "ayam", "minjak" -> "minyak"
        if old == 'j' and 'dj' in text: continue # Skip if part of 'dj'
        if old == 'j' and 'tj' in text: continue # Skip if part of 'tj'
        if old == 'j' and 'nj' in text: continue # Skip if part of 'nj'
        
        text = text.replace(old, new)

    # 6. DOMAIN SPECIFIC MAPPING (Synonyms & Prep Removal)
    # Map synonyms to a canonical name
    synonyms = {
        'brambang': 'bawang merah',
        'lombok': 'cabai',
        'cabe': 'cabai',
        'djae': 'jahe',
        'jae': 'jahe',
        'laos': 'lengkuas',
        'jeruk nipis': 'jeruk', # generalizing citrus if desired
        'jeruk purut': 'jeruk',
        'unclang': 'daun bawang',
        'vetsin': 'penyedap rasa',
        'micin': 'penyedap rasa'
    }
    
    # Remove preparation words
    stop_words = ['iris', 'halus', 'giling', 'potong', 'cincang', 'sisir', 'muda', 'tua', 'matang', 'segar']
    
    words = text.split()
    clean_words = []
    
    for w in words:
        if w in synonyms:
            clean_words.append(synonyms[w])
        elif w not in stop_words:
            clean_words.append(w)
            
    return ' '.join(clean_words).strip()

# %%
df_ingredients
# Out:
#                id   recipe_id ingredient_group ingredient_original_name  \
# 0      ING_000001   MR_187_01            utama    djagung putih pipilan
# 1      ING_000002   MR_187_02            kulit                    beras
# 2      ING_000003   MR_187_02            kulit                    garam
# 3      ING_000004   MR_187_02            kulit         daun pisang batu
# 4      ING_000005   MR_187_02            kulit                   biting
# ...           ...         ...              ...                      ...
# 13813  ING_013814  MR_1163_03            utama                   kelapa
# 13814  ING_013815  MR_1163_03            utama             santan tjair
# 13815  ING_013816  MR_1163_03            utama            santan kental
# 13816  ING_013817  MR_1163_03            utama              kelapa muda
# 13817  ING_013818  MR_1163_03            utama                     gula
#
#       ingredient_normalized_name ingredient_quantity ingredient_unit
# 0           jagung putih pipilan                None             NaN
# 1                          beras                 1.0           liter
# 2                          garam                 1.0    sendok makan
# 3               daun pisang batu                 2.0         pelepah
# 4                         biting                None      secukupnya
# ...                          ...                 ...             ...
# 13813                     Kelapa                None             NaN
# 13814                santan cair                 3.0           gelas
# 13815              santan kental                 1.0           gelas
# 13816                Kelapa muda                None             NaN
# 13817                       gula                None             NaN
#
# [13818 rows x 7 columns]

# %%
# Apply the function

df_ingredients['ingredient_normalized_name'] = df_ingredients['ingredient_normalized_name'].apply(clean_ingredient_name)
counts = df_ingredients['ingredient_normalized_name'].value_counts()
counts.to_csv('counts.csv')
# Aggregation: Group by the new clean name and sum the counts
#df_clean = df_ingredients.groupby('ingredient_normalized_name')['count'].sum().sort_values(ascending=False).reset_index()

#print(df_clean.head(20))

# %% [markdown]
# ## 3. Data Cleaning Section
# Use this section to fix common OCR issues:
# 1. `None` values in titles.
# 2. Weird characters in units (e.g., "lt." vs "liter").
# 3. Standardize regions.

# %%
# Example: Check for missing Normalized Titles
missing_titles = df_recipes[df_recipes['title_normalized'].isnull()]
print(f"Recipes with missing titles: {len(missing_titles)}")
missing_titles.head()
# Out:
# Recipes with missing titles: 0
# Empty DataFrame
# Columns: [id, title_original, title_normalized, source_page, region, ai_category, ingredient_json, instruction, region_clean, province_group, category]
# Index: []

# %%
# Example: Normalize Units (Basic clean)
print("Top 20 Unique Units:")
print(df_ingredients['ingredient_unit'].value_counts().head(100))

# TODO: Add replacement logic here
# df_ingredients['ingredient_unit'] = df_ingredients['ingredient_unit'].replace({...})
# Out:
# Top 20 Unique Units:
# ingredient_unit
# sendok makan            1776
# buah                    1749
# sendok teh              1434
# butir                   1109
# kilogram                1045
#                         ...
# rantang                    1
# tunas                      1
# sampai ikan terendam       1
# juring                     1
# kalo                       1
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# ## 4. Export to CSV
# Save the raw tables to disk before deep cleaning.

# %%
df_recipes.to_csv("df_recipes.csv", index=False)
df_ingredients.to_csv("df_ingredient_recipes.csv", index=False)
